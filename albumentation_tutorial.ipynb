# %%
import albumentations as A
import cv2
import matplotlib.pyplot as plt

# %%
import albumentations as A
import cv2

image1 = cv2.imread("../Data/test/1.jpg")
image2 = cv2.imread("../Data/test/4.jpg")
print(image1)
height = 600
width = 600

image = image1
# Declare an augmentation pipeline
transform = A.Compose([
    #A.Resize(height=height, width=width),
    A.RandomResizedCrop(
            height=600, 
            width=600, 
            scale=(0.24, 0.26),
            ratio=(0.90, 1.10),
            always_apply=True
            ),
    A.HorizontalFlip(p=0.5),
    A.Normalize(mean=(0.548, 0.504, 0.479), std=(0.237, 0.247, 0.246))
    #A.pytorch.transforms.ToTensorV2()
])

augmentations = transform(image=image)
augmentation_img = augmentations["image"]

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.grid(False)
plt.imshow(image, cmap=plt.cm.binary)

plt.subplot(2,2,2)
plt.imshow(augmentation_img, cmap=plt.cm.binary)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[201 199 198]
#   [200 198 197]
#   [198 196 195]
#   ...
#   [138 136 136]
#   [138 136 136]
#   [138 136 136]]
#
#  [[202 200 199]
#   [201 199 198]
#   [199 197 196]
#   ...
#   [138 136 136]
#   [138 136 136]
#   [138 136 136]]
#
#  [[201 199 198]
#   [201 199 198]
#   [200 198 197]
#   ...
#   [138 136 136]
#   [138 136 136]
#   [138 136 136]]
#
#  ...
#
#  [[149 149 149]
#   [148 148 148]
#   [147 147 147]
#   ...
#   [ 84  80  85]
#   [ 86  82  87]
#   [ 85  81  86]]
#
#  [[150 150 150]
#   [149 149 149]
#   [148 148 148]
#   ...
#   [ 82  78  83]
#   [ 85  81  86]
#   [ 84  80  85]]
#
#  [[150 150 150]
#   [150 150 150]
#   [148 148 148]
#   ...
#   [ 81  77  82]
#   [ 83  79  84]
#   [ 84  80  85]]]

# %%
import albumentations as A
import cv2

image1 = cv2.imread("../Data/test/1.jpg")
image2 = cv2.imread("../Data/test/4.jpg")

height = 1000
width = 1000

image = image2
# Declare an augmentation pipeline
transform = A.Compose([
     #A.Resize(height = height, width = width),   # (h, w)
            #A.Transpose(p=0.5),
            
            A.CenterCrop(always_apply=True, p=1.0, height=600, width=600),
            # #A.RandomResizedCrop(height = 600,  width = 600 , scale=(0.32, 0.34),
            # ratio=(0.90, 1.10),
            # always_apply=True),
            A.HorizontalFlip(p=0.5),
            #A.VerticalFlip(p=0.5),
            #A.ShiftScaleRotate(p=0.5),
#             GaussNoise(p=0.7),
#             HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             RandomBrightnessContrast(brightness_limit=(-0.1,0.1), contrast_limit=(-0.1, 0.1), p=0.5),
            # A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
           # A.CoarseDropout(p=0.5),
           # A.Cutout(p=0.5),
],p=1.)

augmentations = transform(image=image)
augmentation_img = augmentations["image"]

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.grid(False)
plt.imshow(image, cmap=plt.cm.binary)

plt.subplot(2,2,2)
plt.imshow(augmentation_img, cmap=plt.cm.binary)
plt.show()
