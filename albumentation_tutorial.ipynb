# %%
import albumentations as A
import cv2
import matplotlib.pyplot as plt

image1 = cv2.imread("../efficientnet_pytorch/test_data/avan2.jpg")
image2 = cv2.imread("../efficientnet_pytorch/test_data/avan2.jpg")
height = 300
width = 300

image = image1
# Declare an augmentation pipeline
transform = A.Compose([
#    A.Resize(height=height, width=width),
#    A.CenterCrop(always_apply=True,p=1.0, height=300, width=300),
    A.RandomResizedCrop(
    height = 300,
    width = 300,
    scale=(0.66, 0.70),
    ratio=(0.90, 1.10),
    always_apply=True),
#    A.HorizontalFlip(p=0.5),
#    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0)
    #A.pytorch.transforms.ToTensorV2()
])

augmentations = transform(image=image)
augmentation_img = augmentations["image"]

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.grid(False)
plt.imshow(image, cmap=plt.cm.binary)

plt.subplot(2,2,2)
plt.imshow(augmentation_img, cmap=plt.cm.binary)
plt.show()

# %%
import albumentations as A
import cv2

image1 = cv2.imread("../Data/test/3.jpg")
image2 = cv2.imread("../Data/test/4.jpg")

height = 1000
width = 1000

image = image1
# Declare an augmentation pipeline
transform = A.Compose([
     #A.Resize(height = height, width = width),   # (h, w)
            #A.Transpose(p=0.5),
            
            A.CenterCrop(always_apply=True, p=1.0, height=500, width=800),
            A.RandomResizedCrop(
            height = 300,
            width = 300,
            scale=(0.26, 0.30),
            ratio=(0.80, 1.10),
            always_apply=True),
#            A.HorizontalFlip(p=0.5),
#            A.Transpose(p=0.5),
            #A.VerticalFlip(p=0.5),
            #A.ShiftScaleRotate(p=0.5),
#             GaussNoise(p=0.7),
#             HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
            A.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.2), 
            A.RandomBrightnessContrast(
                 brightness_limit=0.2,
                 contrast_limit=0.2,
                 p=1),
            # A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
           # A.CoarseDropout(p=0.5),
           # A.Cutout(p=0.5),
],p=1.)

augmentations = transform(image=image)
augmentation_img = augmentations["image"]

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.grid(False)
plt.imshow(image, cmap=plt.cm.binary)

plt.subplot(2,2,2)
plt.imshow(augmentation_img, cmap=plt.cm.binary)
plt.show()

# %%
import albumentations as A
import cv2

image1 = cv2.imread("../Data/test/1.jpg")
image2 = cv2.imread("../Data/test/3.jpg")

height = 500
width = 800

image = image1
# Declare an augmentation pipeline
transform = A.Compose([
            
    
            A.Resize(height = 300, width = 600),   # (h, w)
            #A.Transpose(p=0.5),
            A.RandomCrop(always_apply=False, p=1.0, height=300, width=300)
            # A.RandomResizedCrop(
            # height = 300,
            # width = 300,
            # scale=(0.92, 0.96),
            # ratio=(0.80, 1.10),
            # always_apply=True),
#            A.HorizontalFlip(p=0.5),
#            A.Transpose(p=0.5),
            #A.VerticalFlip(p=0.5),
            #A.ShiftScaleRotate(p=0.5),
#             GaussNoise(p=0.7),
#             HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
            # A.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.2), 
            # A.RandomBrightnessContrast(
            #      brightness_limit=0.2,
            #      contrast_limit=0.2,
            #      p=1),
            # A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
           # A.CoarseDropout(p=0.5),
           # A.Cutout(p=0.5),
],p=1.)

augmentations = transform(image=image)
augmentation_img = augmentations["image"]

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.grid(False)
plt.imshow(image, cmap=plt.cm.binary)

plt.subplot(2,2,2)
plt.imshow(augmentation_img, cmap=plt.cm.binary)
plt.show()

# %%
# Out:
# LabelEncoder()

# %%
le.inverse_transform([4])
# Out:
# array(['기아/K3/2017'], dtype='<U15')
